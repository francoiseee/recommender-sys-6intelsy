# %% [markdown]
# # 01 — Exploratory Data Analysis
# ### Personalized Recommendation with Contextual Bandits
# #### 6INTELSY Final Project AY 2025–2026
#
# **Goal:** Understand the dataset before modeling — distributions, class balance, text lengths, etc.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style='whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 1. Load Data

# %%
# TODO: Load dataset after running data/get_data.py
# df = pd.read_csv('../data/processed/dataset.csv')
# df.head()

# %% [markdown]
# ## 2. Basic Statistics

# %%
# TODO: df.describe()
# TODO: df.info()

# %% [markdown]
# ## 3. Text Length Distribution

# %%
# TODO: Plot distribution of text lengths (tokens)
# text_lengths = df['text'].apply(lambda x: len(x.split()))
# text_lengths.hist(bins=50)

# %% [markdown]
# ## 4. Category / Label Distribution

# %%
# TODO: df['category'].value_counts().plot(kind='bar')

# %% [markdown]
# ## 5. Key EDA Findings
#
# *(Fill in after running analysis)*
#
# - Finding 1:
# - Finding 2:
# - Finding 3:
